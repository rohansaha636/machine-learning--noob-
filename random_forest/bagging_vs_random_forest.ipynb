# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier,BaggingClassifier
from sklearn.datasets import make_classification
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_samples =100,n_features =5,n_redundant =0,n_clusters_per_class=1,n_informative=5)

# %%
df =pd.DataFrame(X,columns =['col1','col2','col3','col4','col5'])
df['target'] =y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -0.774678  0.609344  1.382493 -0.743882 -0.906414       0
# 1 -1.488776  1.026466 -1.040429 -1.534640 -0.222670       0
# 2 -0.755619  1.491222  2.077556 -1.163705 -1.105242       0
# 3  2.079081 -1.772268  0.528428 -0.181828 -1.143395       1
# 4 -2.612843  1.955803 -1.229905 -1.157579 -1.067379       0

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(X,y)
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(10,10))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features=2)

# %%
rf.fit(X,y)
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[4])
plt.show()
