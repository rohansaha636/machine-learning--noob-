# %% [markdown]
# first we will import pandas

# %%
import pandas as pd

# %% [markdown]
# then we will import csv files

# %%
df =pd.read_csv('favorite_music_dataset.csv')
df
# Out:
#            Song_Title                         Artist       Genre  \
# 0               Faded                    Alan Walker  Electronic
# 1     Blinding Lights                     The Weeknd   Synth-pop
# 2               Faded                    Alan Walker  Electronic
# 3               Faded                    Alan Walker  Electronic
# 4   Bohemian Rhapsody                          Queen        Rock
# ..                ...                            ...         ...
# 95     Counting Stars                    OneRepublic    Pop Rock
# 96           Senorita  Shawn Mendes & Camila Cabello   Latin Pop
# 97     Counting Stars                    OneRepublic    Pop Rock
# 98    Blinding Lights                     The Weeknd   Synth-pop
# 99         Let Her Go                      Passenger       Indie
#
#     Release_Year  Duration_Minutes Listened_Date     Platform
# 0           2024              4.02    2024-02-10  Apple Music
# ...

# %% [markdown]
# we will read csv files from url

# %%
import requests
from io import StringIO
url= "https://raw.githubusercontent.com/Currie32/500-Greatest-Albums/master/albumlist.csv"
header ={ 'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
req = requests.get(url,headers = header)
data =StringIO(req.text)

pd.read_csv(data)
# Out:
#      Number  Year                                  Album             Artist  \
# 0         1  1967  Sgt. Pepper's Lonely Hearts Club Band        The Beatles
# 1         2  1966                             Pet Sounds     The Beach Boys
# 2         3  1966                               Revolver        The Beatles
# 3         4  1965                   Highway 61 Revisited          Bob Dylan
# 4         5  1965                            Rubber Soul        The Beatles
# ..      ...   ...                                    ...                ...
# 495     496  1969                             Boz Scaggs         Boz Scaggs
# 496     497  2001                      White Blood Cells  The White Stripes
# 497     498  1989                        The Stone Roses    The Stone Roses
# 498     499  1971               Live in Cook County Jail          B.B. King
# 499     500  1998                               Aquemini            OutKast
#
# ...

# %% [markdown]
# use cols_parameter

# %%
pd.read_csv('favorite_music_dataset.csv',usecols=['Listened_Date','Genre'])
# Out:
#          Genre Listened_Date
# 0   Electronic    2024-02-10
# 1    Synth-pop    2024-05-30
# 2   Electronic    2024-05-07
# 3   Electronic    2024-03-19
# 4         Rock    2024-01-16
# ..         ...           ...
# 95    Pop Rock    2024-05-30
# 96   Latin Pop    2024-06-11
# 97    Pop Rock    2024-01-03
# 98   Synth-pop    2024-06-13
# 99       Indie    2024-01-04
#
# [100 rows x 2 columns]

# %% [markdown]
# it will helps us to filter the data from csv files

# %% [markdown]
# Header parameter

# %%
pd.read_csv('favorite_music_dataset.csv',header = 1)
# Out:
#                 Faded                    Alan Walker  Electronic  2024  4.02  \
# 0     Blinding Lights                     The Weeknd   Synth-pop  2018  4.45
# 1               Faded                    Alan Walker  Electronic  2024  4.86
# 2               Faded                    Alan Walker  Electronic  2012  4.92
# 3   Bohemian Rhapsody                          Queen        Rock  2023  3.90
# 4             Perfect                     Ed Sheeran  Pop Ballad  2014  4.65
# ..                ...                            ...         ...   ...   ...
# 94     Counting Stars                    OneRepublic    Pop Rock  2013  3.40
# 95           Senorita  Shawn Mendes & Camila Cabello   Latin Pop  2024  2.75
# 96     Counting Stars                    OneRepublic    Pop Rock  2010  3.57
# 97    Blinding Lights                     The Weeknd   Synth-pop  2012  4.04
# 98         Let Her Go                      Passenger       Indie  2013  4.61
#
#     2024-02-10  Apple Music
# ...

# %% [markdown]
# skiprows and nrows

# %%
pd.read_csv('favorite_music_dataset.csv',skiprows=[0,4],nrows =10)
# Out:
#                Faded     Alan Walker  Electronic  2024  4.02  2024-02-10  \
# 0    Blinding Lights      The Weeknd   Synth-pop  2018  4.45  2024-05-30
# 1              Faded     Alan Walker  Electronic  2024  4.86  2024-05-07
# 2  Bohemian Rhapsody           Queen        Rock  2023  3.90  2024-01-16
# 3            Perfect      Ed Sheeran  Pop Ballad  2014  4.65  2024-01-24
# 4         Let Her Go       Passenger       Indie  2020  3.39  2024-03-03
# 5    Blinding Lights      The Weeknd   Synth-pop  2011  2.67  2024-06-05
# 6         Let Her Go       Passenger       Indie  2016  4.05  2024-06-26
# 7  Bohemian Rhapsody           Queen        Rock  2015  3.98  2024-02-10
# 8             Havana  Camila Cabello   Latin Pop  2018  4.01  2024-04-02
# 9         Photograph      Ed Sheeran         Pop  2014  4.24  2024-03-24
#
#    Apple Music
# 0     Zing MP3
# 1     Zing MP3
# 2  Apple Music
# 3  Apple Music
# 4      Spotify
# 5      YouTube
# 6      YouTube
# 7      Spotify
# 8      Spotify
# ...

# %% [markdown]
# dtype datatype

# %%
df = pd.read_csv('favorite_music_dataset.csv', dtype={'Duration_Minutes ': int})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Song_Title        100 non-null    object
#  1   Artist            100 non-null    object
#  2   Genre             100 non-null    object
#  3   Release_Year      100 non-null    int64
#  4   Duration_Minutes  100 non-null    float64
#  5   Listened_Date     100 non-null    object
#  6   Platform          100 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 5.6+ KB

# %% [markdown]
# breaking the data in chunks to make tha data small

# %%
dfs =pd.read_csv('favorite_music_dataset.csv',chunksize=20)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (20, 7)
# (20, 7)
# (20, 7)
# (20, 7)
# (20, 7)

# %% [markdown]
# CONVERTORS

# %%
pd.read_csv('Cricket_data.csv')
# Out:
#       season       id                                          name  \
# 0        NaN  1370350          Chennai Super Kings v Gujarat Titans
# 1        NaN  1370351         Lucknow Super Giants v Mumbai Indians
# 2        NaN  1370352                                     TBC v TBC
# 3        NaN  1370353                                     TBC v TBC
# 4     2023.0  1359544  Royal Challengers Bangalore v Gujarat Titans
# ...      ...      ...                                           ...
# 1027  2008.0   336012  Royal Challengers Bangalore v Mumbai Indians
# 1028  2008.0   336019            Kings XI Punjab v Rajasthan Royals
# 1029  2008.0   336038           Delhi Daredevils v Rajasthan Royals
# 1030  2008.0   336039         Chennai Super Kings v Kings XI Punjab
# 1031  2008.0   336040        Chennai Super Kings v Rajasthan Royals
#
#       short_name                                        description home_team  \
# ...

# %%
def rename(name):
    if name == "RCB":
        return "royal challengers bangalore"
    else:
        return name

# %%
rename("RCB")
# Out:
# 'royal challengers bangalore'

# %%
pd.read_csv('Cricket_data.csv',converters={'home_team': rename})
# Out:
#       season       id                                          name  \
# 0        NaN  1370350          Chennai Super Kings v Gujarat Titans
# 1        NaN  1370351         Lucknow Super Giants v Mumbai Indians
# 2        NaN  1370352                                     TBC v TBC
# 3        NaN  1370353                                     TBC v TBC
# 4     2023.0  1359544  Royal Challengers Bangalore v Gujarat Titans
# ...      ...      ...                                           ...
# 1027  2008.0   336012  Royal Challengers Bangalore v Mumbai Indians
# 1028  2008.0   336019            Kings XI Punjab v Rajasthan Royals
# 1029  2008.0   336038           Delhi Daredevils v Rajasthan Royals
# 1030  2008.0   336039         Chennai Super Kings v Kings XI Punjab
# 1031  2008.0   336040        Chennai Super Kings v Rajasthan Royals
#
#       short_name                                        description  \
# 0       CSK v GT  Qualifier 1 (N), Indian Premier League at Chen...
# ...

# %% [markdown]
# welll it did not worked properly as intended but process is ok
