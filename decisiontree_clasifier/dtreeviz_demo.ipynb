# %%
# %pip install dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in c:\users\rohan\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in c:\users\rohan\anaconda3\lib\site-packages (from dtreeviz) (0.21)
# Requirement already satisfied: pandas in c:\users\rohan\anaconda3\lib\site-packages (from dtreeviz) (2.2.3)
# Requirement already satisfied: numpy in c:\users\rohan\anaconda3\lib\site-packages (from dtreeviz) (2.1.3)
# Requirement already satisfied: scikit-learn in c:\users\rohan\anaconda3\lib\site-packages (from dtreeviz) (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\rohan\anaconda3\lib\site-packages (from dtreeviz) (3.10.0)
# Requirement already satisfied: colour in c:\users\rohan\anaconda3\lib\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in c:\users\rohan\anaconda3\lib\site-packages (from dtreeviz) (8.3.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rohan\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rohan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rohan\anaconda3\lib\site-packages (from pandas->dtreeviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rohan\anaconda3\lib\site-packages (from pandas->dtreeviz) (2025.2)
# Requirement already satisfied: colorama in c:\users\rohan\anaconda3\lib\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\rohan\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\rohan\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\rohan\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rohan\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image ,display_svg,SVG
import dtreeviz

# %%
clas = tree.DecisionTreeClassifier()
iris = load_iris()
X_train = iris.data
y_train = iris.target
clas.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# 1. CLASSIFICATION

# %%
viz_model = dtreeviz.model(
    clas,
    X_train,
    y_train,
    feature_names=iris.feature_names,
    class_names=["setosa", "versicolor", "virginica"]
)
viz_model.view()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\rohan\anaconda3\Lib\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File c:\Users\rohan\anaconda3\Lib\subprocess.py:554, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     552     kwargs['stderr'] = PIPE
# --> 554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
#
# File c:\Users\rohan\anaconda3\Lib\subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#
# File c:\Users\rohan\anaconda3\Lib\subprocess.py:1554, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1553 try:
# -> 1554     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1555                              # no special security
#    1556                              None, None,
#    1557                              int(not close_fds),
#    1558                              creationflags,
#    1559                              env,
#    1560                              cwd,
#    1561                              startupinfo)
#    1562 finally:
#    1563     # Child is launched. Close the parent's copy of those pipe
#    1564     # handles that only the child should have open.  You need
#    (...)
#    1567     # pipe will not close when the child process exits and the
#    1568     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# File c:\Users\rohan\anaconda3\Lib\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File c:\Users\rohan\anaconda3\Lib\site-packages\dtreeviz\utils.py:242, in DTreeVizRender._repr_svg_(self)
#     241 def _repr_svg_(self):
# --> 242     return self.svg()
#
# File c:\Users\rohan\anaconda3\Lib\site-packages\dtreeviz\utils.py:246, in DTreeVizRender.svg(self)
#     244 def svg(self):
#     245     """Render tree as svg and return svg text."""
# --> 246     svgfilename = self.save_svg()
#     247     with open(svgfilename, encoding='UTF-8') as f:
#     248         svg = f.read()
#
# File c:\Users\rohan\anaconda3\Lib\site-packages\dtreeviz\utils.py:266, in DTreeVizRender.save_svg(self)
#     264 tmp = tempfile.gettempdir()
#     265 svgfilename = os.path.join(tmp, f"DTreeViz_{os.getpid()}.svg")
# --> 266 self.save(svgfilename)
#     267 return svgfilename
#
# File c:\Users\rohan\anaconda3\Lib\site-packages\dtreeviz\utils.py:294, in DTreeVizRender.save(self, filename)
#     292     graphviz.backend.run(cmd, capture_output=True, check=True, quiet=False)
#     293 else:
# --> 294     graphviz.backend.execute.run_check(cmd, capture_output=True, check=True, quiet=False)
#     296 if filename.endswith(".svg"):
#     297     # now merge in referenced SVG images to make all-in-one file
#     298     with open(filename, encoding='UTF-8') as f:
#
# File c:\Users\rohan\anaconda3\Lib\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      79 except OSError as e:
#      80     if e.errno == errno.ENOENT:
# ---> 81         raise ExecutableNotFound(cmd) from e
#      82     raise
#      84 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute 'dot', make sure the Graphviz executables are on your systems' PATH
